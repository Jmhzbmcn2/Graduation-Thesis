# %%
import pandas as pd

# %%
file_path = r"C:\Users\VUDUYLINH\PycharmProjects\KLTN\LightRAG\testcase\filtered-articles-on-treatment.csv"

# %%
df = pd.read_csv(file_path, sep=',')
df.to_excel("test_case.xlsx", index=False)

# %%
df
# Out:
#       question_idx                                           question  \
# 0    medicine_8108  Con sâu ngũ bội tử tìm đến cây muối vào thời g...
# 1    medicine_8115  Chất nào trong Ngũ bội tử có tác dụng chống un...
# 2    medicine_8116  Trong mô hình nấm da mở chó, dung dịch từ Ngũ ...
# 3    medicine_8120  Ngũ bội tử được sử dụng như thế nào để điều tr...
# 4    medicine_8112     Thành phần hóa học chính của ngũ bội tử là gì?
# ..             ...                                                ...
# 140   disease_7692  Khi nào các triệu chứng bệnh suy thận bắt đầu ...
# 141   disease_9704                  Ngăn ngừa bệnh trĩ bằng cách nào?
# 142   disease_7706  Để phòng ngừa bệnh suy thận, cần thực hiện lối...
# 143   disease_9681                 Triệu chứng của bệnh trĩ sa là gì?
# 144   disease_9703  Thắt bằng dây thun có thể điều trị bệnh trĩ ở ...
#
#                                                 answer  \
# 0                              Vào khoảng tháng 5 – 6.
# ...
